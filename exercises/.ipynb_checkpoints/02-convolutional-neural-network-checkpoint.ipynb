# %%
import os
import pathlib
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator, img_to_array, array_to_img, load_img
from tensorflow.keras.utils import to_categorical
# %matplotlib inline
# Out:
# /Users/marysia/.pyenv/versions/3.8.3/lib/python3.8/site-packages/pandas/compat/__init__.py:120: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %% [markdown]
# # Convolutional Neural Networks
#
#
# Convolutional Neural Networks are great for image processing tasks. In this notebook, we're going to attempt to build and train our a CNN.
#
# ## The Data
# The dataset we will be using will be a German Traffic Sign Recognition Benchmark (GTSRB) dataset. The dataset consists of 43 different types of road signs found all throughout Germany, and our goal is to correctly determine which traffic sign we have on our image.
#
# Let's start with defining some properties of our data.

# %%
# Path to the data folder. 
data_path = Path('../data/GTSRB')

# Predefined image height and width. 
IMG_HEIGHT = 30
IMG_WIDTH = 30

# Number of classes
NUM_CATEGORIES = 43

# %% [markdown]
# Then let's load the data and immediately one-hot-encode the labels.

# %%
def load_data(data_dir):
    '''
    Loading data from Train folder.
    
    Returns a tuple `(images, labels)` , where `images` is a list of all the images in the train directory,
    where each image is formatted as a numpy ndarray with dimensions IMG_WIDTH x IMG_HEIGHT x 3. 
    `labels` is a list of integer labels, representing the categories for each of the
    corresponding `images`.
    '''
    images = list()
    labels = list()
    for category in range(NUM_CATEGORIES):
        category_dir = data_dir / str(category)
        for img_file in category_dir.glob('*'): 
            img = load_img(img_file, target_size = (IMG_HEIGHT, IMG_WIDTH))
            img_array = img_to_array(img)
            images.append(img_array)
            labels.append(category)
            
    return np.array(images), labels

# %%
# Load the data. 
images, labels = load_data(data_path)

# One hot encoding the labels
labels = to_categorical(labels)

# %% [markdown]
# #### Visualize
# Before we move onto any modelling, let's inspect what kind of images we have in our data. We will create a 7x7 grid as this will fit our 43 categories (with six spaces to spare) and visualise a random instance of each class.

# %%
# Visualizing all the different traffic signs
img_dir = pathlib.Path(data_path)
plt.figure(figsize=(14,14))
index = 0
for i in range(NUM_CATEGORIES):
    plt.subplot(7, 7, i+1)
    plt.grid(False)
    plt.xticks([])
    plt.yticks([])
    sign = list(img_dir.glob(f'{i}/*'))[0]
    img = load_img(sign, target_size=(IMG_WIDTH, IMG_HEIGHT))
    plt.imshow(img)
plt.show()

# %% [markdown]
# ## Data Preparation
#
# Besides loading in the data, we need to split our data into a train and test set.

# %%
x_train, x_test, y_train, y_test = train_test_split(np.array(images), labels, test_size=0.4)

# %% [markdown]
# #### Exercise: Preprocessing
# Can you think of any preprocessing technique that might apply here?

# %%
x_train, x_test = x_train.astype("float") / 255, x_test.astype("float") / 255

# %% [markdown]
# Let's also prepare a train- and evaluation function that will execute the training and evaluation for us.

# %%
def train_and_evaluate(model_func):
    # Create and print model
    model = model_func()
    print(model.summary())
    
    # Compiling the model
    model.compile(
        loss='categorical_crossentropy',
        optimizer='adam',
        metrics=['accuracy']
    )

    # Fitting the model
    epochs = 30
    model.fit(x_train, 
              y_train,
              validation_data = (x_test, y_test), 
              epochs=epochs, 
              batch_size=16
             )
    
    # evaluate
    loss, accuracy = model.evaluate(x_test, y_test)
    print('Test set accuracy: ', accuracy * 100)

# %% [markdown]
# ## Simple model
#
# It's time to create our first version of a model. Let this model have one convolutional layer.
#
# **Exercise**: Create a CNN with one Conv layer and get it to train. Don't worry if the results aren't any good yet!
#
# Hints:
#    * The first convolutional layer must receive an `input_shape`, otherwise it doesn't know what size of images to expect!
#    * Try to set the `filters`, `kernel_size` and `activation` for your convolutional layer. What values would you think are appropriate? Experiment!
#    * A CNN always ends with a fully-connected (Dense) layer and the number of categories as output.
#    * Have you tried going from a Conv2D to Dense immediately? That'll likely lead to an error! In order to be able to use your Dense layer, you must _flatten_ your output feature maps.
#
# Experiment:
#    * Add another Dense layer at the end. How does this influence the result? Do you understand why?
#    * Add two more convolutional layers. How does this influence the training time? How does this influence performance? What happens to the number of parameters?
#    * Experiment with your settings for filters. How does it influence the number of parameters, training time and performance?

# %%
from tensorflow.keras.layers import Conv2D, Flatten, Dense
from tensorflow.keras.models import Sequential

def create_simple_model(): 
    # Create your simple model. 
    model = Sequential()
    model.add(Conv2D(filters=32, kernel_size=3, activation='relu', input_shape=(30,30,3)))
    model.add(Conv2D(filters=64, kernel_size=3, activation='relu'))
    model.add(Conv2D(filters=64, kernel_size=3, activation='relu'))

    model.add(Flatten())
    model.add(Dense(NUM_CATEGORIES, activation='softmax'))
    
    return model


train_and_evaluate(create_simple_model)
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_17 (Conv2D)           (None, 28, 28, 32)        896
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 26, 26, 64)        18496
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 24, 24, 64)        36928
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 36864)             0
# _________________________________________________________________
# dense_6 (Dense)              (None, 43)                1585195
# =================================================================
# Total params: 1,641,515
# Trainable params: 1,641,515
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/30
# 49/49 [==============================] - 2s 51ms/step - loss: 3.5172 - accuracy: 0.1263 - val_loss: 3.0404 - val_accuracy: 0.2447
# Epoch 2/30
# 49/49 [==============================] - 2s 46ms/step - loss: 2.0061 - accuracy: 0.5242 - val_loss: 1.6203 - val_accuracy: 0.5583
# Epoch 3/30
# 49/49 [==============================] - 2s 47ms/step - loss: 0.7192 - accuracy: 0.7997 - val_loss: 1.2477 - val_accuracy: 0.6501
# Epoch 4/30
# 49/49 [==============================] - 2s 45ms/step - loss: 0.2872 - accuracy: 0.9311 - val_loss: 1.5386 - val_accuracy: 0.6444
# Epoch 5/30
# 49/49 [==============================] - 2s 44ms/step - loss: 0.1982 - accuracy: 0.9490 - val_loss: 1.6364 - val_accuracy: 0.6998
# Epoch 6/30
# 49/49 [==============================] - 2s 47ms/step - loss: 0.0936 - accuracy: 0.9821 - val_loss: 1.6313 - val_accuracy: 0.7208
# Epoch 7/30
# 49/49 [==============================] - 2s 48ms/step - loss: 0.0552 - accuracy: 0.9860 - val_loss: 1.5392 - val_accuracy: 0.7533
# Epoch 8/30
# 49/49 [==============================] - 2s 47ms/step - loss: 0.0192 - accuracy: 0.9949 - val_loss: 1.8173 - val_accuracy: 0.7323
# Epoch 9/30
# 49/49 [==============================] - 2s 48ms/step - loss: 0.0155 - accuracy: 0.9974 - val_loss: 1.8349 - val_accuracy: 0.7304
# Epoch 10/30
# 49/49 [==============================] - 2s 50ms/step - loss: 0.0085 - accuracy: 0.9987 - val_loss: 2.0219 - val_accuracy: 0.7400
# Epoch 11/30
# 49/49 [==============================] - 2s 48ms/step - loss: 0.0060 - accuracy: 0.9987 - val_loss: 2.0701 - val_accuracy: 0.7361
# Epoch 12/30
# 49/49 [==============================] - 2s 50ms/step - loss: 0.0049 - accuracy: 0.9974 - val_loss: 2.1522 - val_accuracy: 0.7342
# Epoch 13/30
# 49/49 [==============================] - 2s 49ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 2.1849 - val_accuracy: 0.7361
# Epoch 14/30
# 49/49 [==============================] - 3s 53ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 2.2786 - val_accuracy: 0.7438
# Epoch 15/30
# 49/49 [==============================] - 2s 50ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 2.3635 - val_accuracy: 0.7438
# Epoch 16/30
# 49/49 [==============================] - 2s 48ms/step - loss: 8.5311e-04 - accuracy: 1.0000 - val_loss: 2.4601 - val_accuracy: 0.7419
# Epoch 17/30
# 49/49 [==============================] - 2s 48ms/step - loss: 7.9021e-04 - accuracy: 1.0000 - val_loss: 2.5080 - val_accuracy: 0.7400
# Epoch 18/30
# 49/49 [==============================] - 2s 47ms/step - loss: 6.1711e-04 - accuracy: 1.0000 - val_loss: 2.5850 - val_accuracy: 0.7438
# Epoch 19/30
# 49/49 [==============================] - 2s 48ms/step - loss: 5.5640e-04 - accuracy: 1.0000 - val_loss: 2.6285 - val_accuracy: 0.7419
# Epoch 20/30
# 49/49 [==============================] - 2s 49ms/step - loss: 4.9382e-04 - accuracy: 1.0000 - val_loss: 2.6929 - val_accuracy: 0.7323
# Epoch 21/30
# 49/49 [==============================] - 2s 47ms/step - loss: 4.4538e-04 - accuracy: 1.0000 - val_loss: 2.7179 - val_accuracy: 0.7380
# Epoch 22/30
# 49/49 [==============================] - 2s 48ms/step - loss: 4.3167e-04 - accuracy: 1.0000 - val_loss: 2.7627 - val_accuracy: 0.7380
# Epoch 23/30
# 49/49 [==============================] - 2s 47ms/step - loss: 3.4294e-04 - accuracy: 1.0000 - val_loss: 2.7977 - val_accuracy: 0.7323
# Epoch 24/30
# 49/49 [==============================] - 2s 48ms/step - loss: 3.0539e-04 - accuracy: 1.0000 - val_loss: 2.8452 - val_accuracy: 0.7380
# Epoch 25/30
# 49/49 [==============================] - 2s 45ms/step - loss: 2.6827e-04 - accuracy: 1.0000 - val_loss: 2.8734 - val_accuracy: 0.7323
# Epoch 26/30
# 49/49 [==============================] - 2s 49ms/step - loss: 2.4579e-04 - accuracy: 1.0000 - val_loss: 2.9030 - val_accuracy: 0.7380
# Epoch 27/30
# 49/49 [==============================] - 2s 47ms/step - loss: 2.2779e-04 - accuracy: 1.0000 - val_loss: 2.9540 - val_accuracy: 0.7380
# Epoch 28/30
# 49/49 [==============================] - 2s 47ms/step - loss: 2.0430e-04 - accuracy: 1.0000 - val_loss: 2.9867 - val_accuracy: 0.7361
# Epoch 29/30
# 49/49 [==============================] - 2s 46ms/step - loss: 1.8670e-04 - accuracy: 1.0000 - val_loss: 3.0074 - val_accuracy: 0.7380
# Epoch 30/30
# 49/49 [==============================] - 2s 46ms/step - loss: 1.6332e-04 - accuracy: 1.0000 - val_loss: 3.0448 - val_accuracy: 0.7380
# 17/17 [==============================] - 0s 16ms/step - loss: 3.0448 - accuracy: 0.7380
# Test set accuracy:  73.80496859550476

# %% [markdown]
# ## Spatial reduction
#
# Use the model you build earlier and add spatial reduction - either in the form of max pooling layers or setting the stride of the convolutions.
#
# **Exercise**: Build a model with spatial reduction. Try both max pooling and setting the stride. What influence does this have on the number of parameters and the training time? What influence does this have on the final accuracy? Is this what you expect? Can you think of a reason why spatial reduction may be beneficial?

# %%
from tensorflow.keras.layers import MaxPool2D

def create_spatial_reduction_model():
    model = Sequential()
    model.add(...)
    
    return model

train_and_evaluate(create_spatial_reduction_model)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-80dba5e51dfa> in <module>
#       7     return model
#       8
# ----> 9 train_and_evaluate(create_spatial_reduction_model)
#
# <ipython-input-16-0882b20cc3c1> in train_and_evaluate(model_func)
#       1 def train_and_evaluate(model_func):
#       2     # Create and print model
# ----> 3     model = model_func()
#       4     print(model.summary())
#       5
#
# <ipython-input-21-80dba5e51dfa> in create_spatial_reduction_model()
#       3 def create_spatial_reduction_model():
#       4     model = Sequential()
# ----> 5     model.add(...)
#       6
#       7     return model
#
# ~/.pyenv/versions/3.8.3/lib/python3.8/site-packages/tensorflow/python/training/tracking/base.py in _method_wrapper(self, *args, **kwargs)
#     455     self._self_setattr_tracking = False  # pylint: disable=protected-access
#     456     try:
# --> 457       result = method(self, *args, **kwargs)
#     458     finally:
#     459       self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# ~/.pyenv/versions/3.8.3/lib/python3.8/site-packages/tensorflow/python/keras/engine/sequential.py in add(self, layer)
#     178
#     179     if not isinstance(layer, base_layer.Layer):
# --> 180       raise TypeError('The added layer must be '
#     181                       'an instance of class Layer. '
#     182                       'Found: ' + str(layer))
#
# TypeError: The added layer must be an instance of class Layer. Found: Ellipsis

# %% [markdown]
# ## Regularization
#
# Let's expand the previous model with some regularization techniques! Specifically, dropout and batch normalization.
#
# #### Dropout
# Dropout is a technique that prevents that the network becomes too sensitive to the weight of specific neurons. While training, a node may temporarily be deactivated to ensure the contribution of the node is removed. This ensures predictions do not become too dependent on particular neurons. Dropout is generally applied after the non-linearity (ReLU), and it is of the utmost important to deactivate dropout when evaluating the model on the validation or test set. Luckily, Keras handles this for you.
#
# In a fully-connected network, a common value for dropout is `0.5`. However, in a convolutional neural network, we prefer to set that value to `0.2-0.3`. Can you think of a reason why?
#
# #### Batch Normalization
#
# Another layer typically inserted in a convolutional neural network is the Batch Normalization layer. This ensures that the output of the (convolutional) layer takes on a Gaussian distribution (with an initial zero mean and unit variance, that is adjusted throughout the learning process). Batch normalisation decreases the difficulty of training the network and allows the network to be more robust against a bad initial choice of weights.
#
# **Exercise**: Introduce Batch Normalization and Dropout into your network.

# %%
from tensorflow.keras.layers import Dropout, BatchNormalization
from tensorflow.keras.models import Sequential

def create_model():  
    model = Sequential()
    model.add(...)
    
    return model

train_and_evaluate(create_model)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-1fea0f547984> in <module>
#       8     return model
#       9
# ---> 10 train_and_evaluate(create_model)
#
# <ipython-input-16-0882b20cc3c1> in train_and_evaluate(model_func)
#       1 def train_and_evaluate(model_func):
#       2     # Create and print model
# ----> 3     model = model_func()
#       4     print(model.summary())
#       5
#
# <ipython-input-20-1fea0f547984> in create_model()
#       4 def create_model():
#       5     model = Sequential()
# ----> 6     model.add(...)
#       7
#       8     return model
#
# ~/.pyenv/versions/3.8.3/lib/python3.8/site-packages/tensorflow/python/training/tracking/base.py in _method_wrapper(self, *args, **kwargs)
#     455     self._self_setattr_tracking = False  # pylint: disable=protected-access
#     456     try:
# --> 457       result = method(self, *args, **kwargs)
#     458     finally:
#     459       self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# ~/.pyenv/versions/3.8.3/lib/python3.8/site-packages/tensorflow/python/keras/engine/sequential.py in add(self, layer)
#     178
#     179     if not isinstance(layer, base_layer.Layer):
# --> 180       raise TypeError('The added layer must be '
#     181                       'an instance of class Layer. '
#     182                       'Found: ' + str(layer))
#
# TypeError: The added layer must be an instance of class Layer. Found: Ellipsis

# %% [markdown]
# # Final Exercise
#
# Create the best model you can!
#
# Feel free to experiment with everything you've seen so far. The model architecture (number of layers, hyperparameters of the layers, etc.), but also the training hyperparameters (number of epochs, optimizer, etc.).

# %%
def create_model(): 
    model = Sequential()
    model.add(Conv2D(filters=16, kernel_size=3, activation='relu', input_shape=(30,30,3)))
    model.add(Conv2D(filters=32, kernel_size=3, activation='relu'))
    model.add(MaxPool2D(pool_size=(2, 2)))
    model.add(BatchNormalization())
    
    model.add(Conv2D(filters=64, kernel_size=3, activation='relu'))
    model.add(Conv2D(filters=128, kernel_size=3, activation='relu'))
    model.add(MaxPool2D(pool_size=(2, 2)))
    model.add(BatchNormalization())

    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))
    
    model.add(Dense(NUM_CATEGORIES, activation='softmax'))
    return model

model = create_model()
model.summary()
# Out:
# Model: "sequential_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_30 (Conv2D)           (None, 28, 28, 16)        448
# _________________________________________________________________
# conv2d_31 (Conv2D)           (None, 26, 26, 32)        4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 13, 13, 32)        0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 13, 13, 32)        128
# _________________________________________________________________
# conv2d_32 (Conv2D)           (None, 11, 11, 64)        18496
# _________________________________________________________________
# conv2d_33 (Conv2D)           (None, 9, 9, 128)         73856
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 4, 4, 128)         512
# _________________________________________________________________
# flatten_9 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_11 (Dense)             (None, 512)               1049088
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_12 (Dense)             (None, 43)                22059
# =================================================================
# Total params: 1,171,275
# Trainable params: 1,169,931
# Non-trainable params: 1,344
# _________________________________________________________________

# %%
# Compiling the model
model.compile(
    loss='categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
    )

# Fitting the model
epochs = 30

aug = ImageDataGenerator(
    rotation_range=10,
    zoom_range=0.15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.15,
    horizontal_flip=False,
    vertical_flip=False,
    fill_mode="nearest")

model.fit(aug.flow(x_train, y_train),
          validation_data = (x_test, y_test), 
          epochs=epochs, 
          batch_size=16
         )
    
# evaluate
loss, accuracy = model.evaluate(x_test, y_test)
print('Test set accuracy: ', accuracy * 100)
# Out:
# Epoch 1/30
# 25/25 [==============================] - 1s 53ms/step - loss: 4.4635 - accuracy: 0.0880 - val_loss: 3.6469 - val_accuracy: 0.0669
# Epoch 2/30
# 25/25 [==============================] - 1s 55ms/step - loss: 3.4404 - accuracy: 0.1952 - val_loss: 3.5999 - val_accuracy: 0.1281
# Epoch 3/30
# 25/25 [==============================] - 1s 57ms/step - loss: 2.7834 - accuracy: 0.3151 - val_loss: 3.6463 - val_accuracy: 0.0650
# Epoch 4/30
# 25/25 [==============================] - 1s 55ms/step - loss: 2.4602 - accuracy: 0.3839 - val_loss: 3.7585 - val_accuracy: 0.0650
# Epoch 5/30
# 25/25 [==============================] - 1s 51ms/step - loss: 2.0515 - accuracy: 0.4337 - val_loss: 3.9164 - val_accuracy: 0.0650
# Epoch 6/30
# 25/25 [==============================] - 1s 55ms/step - loss: 1.8182 - accuracy: 0.4962 - val_loss: 3.9744 - val_accuracy: 0.0841
# Epoch 7/30
# 25/25 [==============================] - 1s 53ms/step - loss: 1.5175 - accuracy: 0.5702 - val_loss: 4.4389 - val_accuracy: 0.0535
# Epoch 8/30
# 25/25 [==============================] - 1s 53ms/step - loss: 1.3701 - accuracy: 0.6059 - val_loss: 4.4874 - val_accuracy: 0.1090
# Epoch 9/30
# 25/25 [==============================] - 1s 53ms/step - loss: 1.2584 - accuracy: 0.6122 - val_loss: 4.7547 - val_accuracy: 0.0994
# Epoch 10/30
# 25/25 [==============================] - 1s 56ms/step - loss: 1.1612 - accuracy: 0.6556 - val_loss: 4.9044 - val_accuracy: 0.0727
# Epoch 11/30
# 25/25 [==============================] - 1s 57ms/step - loss: 0.9912 - accuracy: 0.6913 - val_loss: 4.7552 - val_accuracy: 0.0822
# Epoch 12/30
# 25/25 [==============================] - 1s 53ms/step - loss: 0.9140 - accuracy: 0.7309 - val_loss: 4.6310 - val_accuracy: 0.1281
# Epoch 13/30
# 25/25 [==============================] - 1s 52ms/step - loss: 0.8419 - accuracy: 0.7398 - val_loss: 4.4957 - val_accuracy: 0.1472
# Epoch 14/30
# 25/25 [==============================] - 1s 51ms/step - loss: 0.7451 - accuracy: 0.7589 - val_loss: 4.7486 - val_accuracy: 0.1166
# Epoch 15/30
# 25/25 [==============================] - 1s 56ms/step - loss: 0.7095 - accuracy: 0.7857 - val_loss: 4.4737 - val_accuracy: 0.1759
# Epoch 16/30
# 25/25 [==============================] - 1s 53ms/step - loss: 0.6430 - accuracy: 0.7946 - val_loss: 3.5332 - val_accuracy: 0.2180
# Epoch 17/30
# 25/25 [==============================] - 1s 58ms/step - loss: 0.5511 - accuracy: 0.8202 - val_loss: 2.9069 - val_accuracy: 0.2887
# Epoch 18/30
# 25/25 [==============================] - 1s 57ms/step - loss: 0.5646 - accuracy: 0.8125 - val_loss: 2.4184 - val_accuracy: 0.3709
# Epoch 19/30
# 25/25 [==============================] - 2s 60ms/step - loss: 0.5061 - accuracy: 0.8431 - val_loss: 2.3475 - val_accuracy: 0.4589
# Epoch 20/30
# 25/25 [==============================] - 1s 57ms/step - loss: 0.4486 - accuracy: 0.8571 - val_loss: 1.6378 - val_accuracy: 0.5430
# Epoch 21/30
# 25/25 [==============================] - 1s 56ms/step - loss: 0.3956 - accuracy: 0.8788 - val_loss: 1.5762 - val_accuracy: 0.5679
# Epoch 22/30
# 25/25 [==============================] - 1s 53ms/step - loss: 0.3747 - accuracy: 0.8827 - val_loss: 1.5070 - val_accuracy: 0.5564
# Epoch 23/30
# 25/25 [==============================] - 1s 51ms/step - loss: 0.3455 - accuracy: 0.8941 - val_loss: 1.2490 - val_accuracy: 0.6424
# Epoch 24/30
# 25/25 [==============================] - 1s 54ms/step - loss: 0.3415 - accuracy: 0.9005 - val_loss: 0.8956 - val_accuracy: 0.7438
# Epoch 25/30
# 25/25 [==============================] - 1s 55ms/step - loss: 0.3605 - accuracy: 0.8852 - val_loss: 0.9506 - val_accuracy: 0.7151
# Epoch 26/30
# 25/25 [==============================] - 2s 68ms/step - loss: 0.3487 - accuracy: 0.8980 - val_loss: 0.7914 - val_accuracy: 0.7419
# Epoch 27/30
# 25/25 [==============================] - 2s 62ms/step - loss: 0.3300 - accuracy: 0.9005 - val_loss: 0.7018 - val_accuracy: 0.7954
# Epoch 28/30
# 25/25 [==============================] - 1s 57ms/step - loss: 0.2930 - accuracy: 0.9094 - val_loss: 0.5538 - val_accuracy: 0.8279
# Epoch 29/30
# 25/25 [==============================] - 2s 61ms/step - loss: 0.2396 - accuracy: 0.9247 - val_loss: 0.4969 - val_accuracy: 0.8547
# Epoch 30/30
# 25/25 [==============================] - 1s 57ms/step - loss: 0.2962 - accuracy: 0.9069 - val_loss: 0.5206 - val_accuracy: 0.8662
# 17/17 [==============================] - 0s 14ms/step - loss: 0.5206 - accuracy: 0.8662
# Test set accuracy:  86.6156816482544
